# %%
import binpack
import matplotlib.pyplot as plt
from binpack.item import Item
from binpack.bin3d import Bin
from binpack.bachelorarbeit import Instance_of_3D_BPP
import pickle
import numpy as np
import time
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib notebook

# %%
bin3d=Bin([1,3,1])
item1=Item([1,1,1])
item2=Item([1,2,1])
items=[item1,item2]
instance= Instance_of_3D_BPP(bin3d,items)

# %%
instance.calculate_difficulty_exact()
print("")
instance.estimate_difficulty(100)
print("")
instance.analyse(1000)
print("")
instance.save_graph()
# Out:
# 48 final states were created
# In the best case 1 Bins were used
# In the worst case 2 Bins were use
# The exact difficulty is: 0.8333333333333335
# Maximum alpha value: 1.0
# Minimum alpha value: 0.5
#
# 100 final states were created
# In the best case 1 Bins were used
# In the worst case 2 Bins were use
# The estimated difficulty is: 0.805
# Maximum alpha value: 1.0
# Minimum alpha value: 0.5
# <img src="data:image/png;base64,..." width="640">
# Saved Graph in Bilder/
